# %% [markdown]
# #**INTRODUCTION**
#
#
# This project is dedicated to the Churn Telco Data. The dataset covers following information concerning a fictional telco company.
#
# This company provides various services such as:
#
# 1.customers, who left within last month(churn)
#
#
# 2.services of each customer
#
#
# 3.customer account information
#
#
# 4.demographic data

# %% [markdown]
# #**DATA SET EXPLANATION**
#
#
#
# 1.CustomerID: A unique ID that identifies each customer.
#
#
# 2.Count: A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
#
#
# 3.Country: The country of the customer’s primary residence.
#
#
# 4.State: The state of the customer’s primary residence.
#
#
# 5.City: The city of the customer’s primary residence.
#
#
# 6.Zip Code: The zip code of the customer’s primary residence.
#
#
# 7.Lat Long: The combined latitude and longitude of the customer’s primary residence.
#
#
# 8.Latitude: The latitude of the customer’s primary residence.
#
#
# 9.Longitude: The longitude of the customer’s primary residence.
#
#
# 10.Gender: The customer’s gender: Male, Female
#
#
# 11.Senior Citizen: Indicates if the customer is 65 or older: Yes, No
#
#
# 12.Partner: Indicate if the customer has a partner: Yes, No
#
#
# 13.Dependents: Indicates if the customer lives with any dependents: Yes, No. Dependents could be children, parents, grandparents, etc.
#
#
# 14.Tenure Months: Indicates the total amount of months that the customer has been with the company by the end of the quarter specified above.
#
#
# 15.Phone Service: Indicates if the customer subscribes to home phone service with the company: Yes, No
#
#
# 16.Multiple Lines: Indicates if the customer subscribes to multiple telephone lines with the company: Yes, No
#
#
# 17.Internet Service: Indicates if the customer subscribes to Internet service with the company: No, DSL, Fiber Optic, Cable.
#
#
# 18.Online Security: Indicates if the customer subscribes to an additional online security service provided by the company: Yes, No
#
#
# 19.Online Backup: Indicates if the customer subscribes to an additional online backup service provided by the company: Yes, No
#
#
# 20.Device Protection: Indicates if the customer subscribes to an additional device protection plan for their Internet equipment provided by the company: Yes, No
#
#
# 21.Tech Support: Indicates if the customer subscribes to an additional technical support plan from the company with reduced wait times: Yes, No
#
#
# 22.Streaming TV: Indicates if the customer uses their Internet service to stream television programming from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
#
# 23.Streaming Movies: Indicates if the customer uses their Internet service to stream movies from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
#
# 24.Contract: Indicates the customer’s current contract type: Month-to-Month, One Year, Two Year.
#
#
# 25.Paperless Billing: Indicates if the customer has chosen paperless billing: Yes, No
#
#
# 26.Payment Method: Indicates how the customer pays their bill: Bank Withdrawal, Credit Card, Mailed Check
#
#
# 27.Monthly Charge: Indicates the customer’s current total monthly charge for all their services from the company.
#
#
# 28.Total Charges: Indicates the customer’s total charges, calculated to the end of the quarter specified above.
#
#
# 29.Churn Label: Yes = the customer left the company this quarter. No = the customer remained with the company. Directly related to Churn Value.
#
#
# 30.Churn Value: 1 = the customer left the company this quarter. 0 = the customer remained with the company. Directly related to Churn Label.
#
#
# 31.Churn Score: A value from 0-100 that is calculated using the predictive tool IBM SPSS Modeler. The model incorporates multiple factors known to cause churn. The higher the score, the more likely the customer will churn.
#
#
# 32.CLTV: Customer Lifetime Value. A predicted CLTV is calculated using corporate formulas and existing data. The higher the value, the more valuable the customer. High value customers should be monitored for churn.
#
#
# 33.Churn Reason: A customer’s specific reason for leaving the company. Directly related to Churn Category.

# %% [markdown]
# ###**IMPORT THE REQUIRED LIBRARY**

# %%
import numpy as np #Importing numpy library
import pandas as pd #Importing pandas library
import matplotlib.pyplot as plt #Importing matplot library
import seaborn as sns # Importing seaborn library

# %% [markdown]
# ###**LOADING THE DATA FILE**

# %%
data=pd.read_excel("Telco_customer_churn.xlsx") # read func is used to read the supermarket_sales file
data #print output
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# ...

# %% [markdown]
# #**BASIC ANALYSIS**

# %% [markdown]
# ###**Now while using the head function we can see first 5 records**

# %%
# set up to view all the info of the columns
pd.set_option('display.max_columns', None) # displaying maximum columns 
data.head() # head function shows first 5 rows of data set
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# ...

# %% [markdown]
# **EXPLANATION**
#
# Using set-option function to get the 33 columns of data set.
#
# **Reason**:when we apply head function it will show the 20 columns by deafult,  we use set option to get the max columns present in the data set.

# %% [markdown]
# ###**Now while using shape attribute we can see the number of rows and columns present in the data set**

# %%
data.shape # using shape function to see the total number of rows and columns present in the table
# Out:
# (7043, 33)

# %% [markdown]
# **EXPLANATION**:
#
# As per the above shape attribute, we have **7043 ROWS and 33 COLUMNS** in the data set.

# %% [markdown]
# ###**Using null function to find the missing values from the data set**

# %%
data.isnull()#if null true otherwise false
# true = 1 and false 0
# Out:
#       CustomerID  Count  Country  State   City  Zip Code  Lat Long  Latitude  \
# 0          False  False    False  False  False     False     False     False
# 1          False  False    False  False  False     False     False     False
# 2          False  False    False  False  False     False     False     False
# 3          False  False    False  False  False     False     False     False
# 4          False  False    False  False  False     False     False     False
# ...          ...    ...      ...    ...    ...       ...       ...       ...
# 7038       False  False    False  False  False     False     False     False
# 7039       False  False    False  False  False     False     False     False
# 7040       False  False    False  False  False     False     False     False
# 7041       False  False    False  False  False     False     False     False
# 7042       False  False    False  False  False     False     False     False
#
# ...

# %% [markdown]
# **EXPLANATION**:
#
# As per the above mentioned output there is missing values in column name :(churn reason) present in the data set.

# %% [markdown]
# ###**To see the statistical part of our data set**

# %%
data.describe() # returns description of the data in the DataFrame
# Out:
#         Count      Zip Code     Latitude    Longitude  Tenure Months  \
# count  7043.0   7043.000000  7043.000000  7043.000000    7043.000000
# mean      1.0  93521.964646    36.282441  -119.798880      32.371149
# std       0.0   1865.794555     2.455723     2.157889      24.559481
# min       1.0  90001.000000    32.555828  -124.301372       0.000000
# 25%       1.0  92102.000000    34.030915  -121.815412       9.000000
# 50%       1.0  93552.000000    36.391777  -119.730885      29.000000
# 75%       1.0  95351.000000    38.224869  -118.043237      55.000000
# max       1.0  96161.000000    41.962127  -114.192901      72.000000
#
#        Monthly Charges  Churn Value  Churn Score         CLTV
# count      7043.000000  7043.000000  7043.000000  7043.000000
# mean         64.761692     0.265370    58.699418  4400.295755
# std          30.090047     0.441561    21.525131  1183.057152
# min          18.250000     0.000000     5.000000  2003.000000
# ...

# %% [markdown]
# **EXPLANATION**:
#
# As per above mentioned output we have descriptive statistics summary of a given dataframe.

# %% [markdown]
# #**Q1.Please read the file and explain data types statistically as well as how python is reading it. Please let us know if any data type is read wrong.**

# %%
data.dtypes # data types of each columns using dtype
# Out:
# CustomerID            object
# Count                float64
# Country               object
# State                 object
# City                  object
# Zip Code             float64
# Lat Long              object
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months        float64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn Label           object
# Churn Value          float64
# Churn Score          float64
# CLTV                 float64
# ...

# %% [markdown]
# **EXPLANATION**:
#
#
# SHOWING PYTHON DATA TYPES AS WRONG:
#
# 1.senior citizen :shows object, its int64
#
# 2.tenure : shows float64, its int64
#
# 3.total charges: shows object, its float64
#
#
# **STATISTICAL DATA TYPES**
#
#
# CustomerID        --   nominal
#
# Count             --   discrete
#
# Country           --   ordinal
#
# State             --  ordinal
#
# City              --  ordinal
#
# Zip Code          --  dicrete
#
# Lat Long          --  continuous
#
# Latitude         --   continuous
#
# Longitude         --  continuous
#
# Gender           --   nominal
#
# Senior Citizen   --   nominal
#
# Partner          --   nominal
#
# Dependents       --   nominal
#
# Tenure Months    --   continuous
#
# Phone Service    --   nomial
#
# Multiple Lines   --   nominal
#
# Internet Service  --  nminal
#
# Online Security   --  nominal
#
# Online Backup     --   nominal
#
# Device Protection  --  nominal
#
# Tech Support      --    nominal
#
# Streaming TV      --    nominal
#
# Streaming Movies  --   nominal
#
# Contract         --    ordinal
#
# Paperless Billing  --  nominal
#
# Payment Method    --   ordinal
#
# Monthly Charges   --   continuous
#
# Total Charges    --    continuous
#
# Churn Label     --     nominal
#
# Churn Value     --     discrete
#
# Churn Score     --     continuous
#
# CLTV            --     discrete

# %% [markdown]
# #**Q2.Please apply appropriate statistical measures using python based on data types.**

# %%
data.info() # using info function to represent the data of columns and non-null count and dtype.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   float64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   float64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   float64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %% [markdown]
# **EXPLANATION**:
#
# I have used info function to get the total number of data types present in the data set to perform statistical measures on selected column.
#
# 2.There are 2 types of data types present in the data set, i selected one random column of each data type to perform analysis.

# %% [markdown]
# **We have 9 columns containing float data type, i have selected one column to perform statistical measures.**

# %%
data['Tenure Months'].describe() # calculating stastistical measures for tenure months
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: Tenure Months, dtype: float64

# %% [markdown]
# **EXPLANATION**:
#
# As per the above output,its showing statistical measures for tenure months.

# %% [markdown]
# #**VARIANCE**

# %%
data['Tenure Months'].var() # calculating variance for tenure months
# Out:
# 603.1681081237301

# %% [markdown]
# #**MEDIAN**

# %%
data['Tenure Months'].median() ## CALCULATING MEDIAN FOR TENURE MONTHS
# Out:
# 29.0

# %%
plt.title(["FIG.1 shows the median value for tenure months"]) # providing title for the plot
sns.boxplot(data["Tenure Months"]) #USING BOX PLOT for MEDIAN VALUE
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **EXPLANATION**:
#
# As per the above box plot it shows the median value is 29.

# %% [markdown]
# #**MODE**

# %%
data['Tenure Months'].mode() # calculating mode of tenure months
# Out:
# 0    1.0
# dtype: float64

# %% [markdown]
# **EXPLANATION**:
#
# 1 MONTH is the mostly used.

# %% [markdown]
# #**IQR-INTER QUARTILE RANGE**

# %%
q3,q1=np.percentile(data["Tenure Months"],[75,25]) # assigning value to the interquartile range 
IQR=q3-q1# calculating interquartile range
IQR #result of IQR
# Out:
# 46.0

# %% [markdown]
# **EXPLANATION**:
#
# Based on the above calculation of IQR, the range is 46.

# %% [markdown]
# #**Q3.What is the percentage of females and senior citizens in this data set? Please create appropriate plots and explain the plots.**

# %% [markdown]
# ##**FEMALES**

# %%
plt.title(["FIG.1 shows the percentage of gender"]) # providing title for the plot
data["Gender"].hist() # show the distribution of gender

# %%
3600/3500 #diving the female count by male count
# Out:
# 1.0285714285714285

# %% [markdown]
# **EXPLANATION**:
#
# The percentage of female is alomost equal to male in the dataset,female is only 1% leser than the male.

# %% [markdown]
# ##**SENIOR CITIZEN**

# %%
plt.title(["FIG.2 shows the percentage senoir citizen"]) # providing title for the plot
data["Senior Citizen"].hist()# show the distribution of senior citizen

# %%
5900/1200
# Out:
# 4.916666666666667

# %% [markdown]
# **EXPLANATION**:
#
# we have 4.91% of senior citizens present in the data set.

# %% [markdown]
# #**Q4.Please create an appropriate plot to examine the distribution of the tenure month column and explain the distribution. Based on distribution, perform appropriate statistical measures. Please also explain if the variable is symmetric or skewed. Please calculate it. Explain everything as asked.**

# %%
plt.title(["FIG. shows the distribution of tenure month"]) # providing title for the plot
data["Tenure Months"].hist() #show the distribution of tenure

# %% [markdown]
# **EXPLANATION**:
#
# This is a normal distribution. And with two peaks, there are two extreme kinds of people among all customers

# %% [markdown]
# ##**STATISTICAL MEASURES**

# %%
data['Tenure Months'].describe() # calculating stastistical measures for tenure months
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: Tenure Months, dtype: float64

# %% [markdown]
# **EXPLANATION**:
#
# As per the above output,its showing statistical measures for tenure months.

# %% [markdown]
# ##**SKEWNESS**

# %%
data['Tenure Months'].skew() # finding skewness for tenure months
# Out:
# 0.2395397495619829

# %% [markdown]
# **EXPLANATION**:
#
# Tenure months data is MODERATE SKEWED ,because the skewness range is in between 0.5.

# %% [markdown]
# #**Q5.Please convert all binary columns into 0 and 1 using appropriate programming constructs, not one by one.**

# %%
data.head()  # head function shows first 5 rows of data set
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK    1.0  United States  California  Los Angeles   90003.0
# 1  9237-HQITU    1.0  United States  California  Los Angeles   90005.0
# 2  9305-CDSKC    1.0  United States  California  Los Angeles   90006.0
# 3  7892-POOKP    1.0  United States  California  Los Angeles   90010.0
# 4  0280-XJGEX    1.0  United States  California  Los Angeles   90015.0
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# ...

# %%
dummy=pd.get_dummies(data["Gender"]) # creating dummies using panda 
dummy.head()  # head function shows first 5 rows of data set
# Out:
#    Female  Male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %% [markdown]
# **EXPLANATION**:
#
# Creating dummies values for gender.

# %%
data1=pd.concat((data,dummy),axis=1) # adding dummy columns into dataset using concat
data1.head()  # head function shows first 5 rows of data set
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK    1.0  United States  California  Los Angeles   90003.0
# 1  9237-HQITU    1.0  United States  California  Los Angeles   90005.0
# 2  9305-CDSKC    1.0  United States  California  Los Angeles   90006.0
# 3  7892-POOKP    1.0  United States  California  Los Angeles   90010.0
# 4  0280-XJGEX    1.0  United States  California  Los Angeles   90015.0
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# ...

# %% [markdown]
# **EXPLANATION**:
#
# Adding dummy values into dataset using axis.

# %%
data1=data1.drop(["Male"],axis=1) #removing male dummy column from data set 
data1.head()  # head function shows first 5 rows of data set
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK    1.0  United States  California  Los Angeles   90003.0
# 1  9237-HQITU    1.0  United States  California  Los Angeles   90005.0
# 2  9305-CDSKC    1.0  United States  California  Los Angeles   90006.0
# 3  7892-POOKP    1.0  United States  California  Los Angeles   90010.0
# 4  0280-XJGEX    1.0  United States  California  Los Angeles   90015.0
#
#                  Lat Long   Latitude   Longitude Senior Citizen Partner  \
# 0  33.964131, -118.272783  33.964131 -118.272783             No      No
# 1   34.059281, -118.30742  34.059281 -118.307420             No      No
# 2  34.048013, -118.293953  34.048013 -118.293953             No      No
# 3  34.062125, -118.315709  34.062125 -118.315709             No     Yes
# 4  34.039224, -118.266293  34.039224 -118.266293             No      No
#
#   Dependents  Tenure Months Phone Service Multiple Lines Internet Service  \
# ...

# %% [markdown]
# **EXPLANATION**:
#
# Removing any one of the dummy column (either male or female), i choose male.

# %%
data1.rename(columns={"Female":"Gender"}) #renaming female column as gender 
data1.head()  # head function shows first 5 rows of data set
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK    1.0  United States  California  Los Angeles   90003.0
# 1  9237-HQITU    1.0  United States  California  Los Angeles   90005.0
# 2  9305-CDSKC    1.0  United States  California  Los Angeles   90006.0
# 3  7892-POOKP    1.0  United States  California  Los Angeles   90010.0
# 4  0280-XJGEX    1.0  United States  California  Los Angeles   90015.0
#
#                  Lat Long   Latitude   Longitude Senior Citizen Partner  \
# 0  33.964131, -118.272783  33.964131 -118.272783             No      No
# 1   34.059281, -118.30742  34.059281 -118.307420             No      No
# 2  34.048013, -118.293953  34.048013 -118.293953             No      No
# 3  34.062125, -118.315709  34.062125 -118.315709             No     Yes
# 4  34.039224, -118.266293  34.039224 -118.266293             No      No
#
#   Dependents  Tenure Months Phone Service Multiple Lines Internet Service  \
# ...

# %% [markdown]
# **Explanation:**
#
# Rename the dummy column with the gender.

# %% [markdown]
# #**Q6.Please examine the distribution of monthly charges between males and females using box plots. Please explain the results also.**

# %%
plt.title(["FIG. shows the distribution of Monthly charges  and  Gender"]) # providing title for the plot
sns.boxplot(x=data['Gender'], y=data['Monthly Charges']) #using box plot and providing x-axis and y-axis.

# %% [markdown]
# **EXPLANATION**:
#
# 1.Both male and female monthly charges are equal.
#
# 2.min and max monthly charges are also equal on both make and female.
#
# 3.median of both genders are 70.

# %% [markdown]
# #**Q8.Please find which payment method has the highest churn score and which has the lowest churn score.**

# %%
plt.title(["FIG. shows the distribution of Payment Method  and  Churn score"]) # providing title for the plot
sns.boxplot(x=data['Payment Method'], y=data['Churn Score'])  #using box plot and providing x-axis and y-axis.

# %% [markdown]
# **EXPLANATION**:
#
# 1.Electronic check has the highest churn score compare to others.
#
# 2.Rest of three payments methods are lowest churn score compare to electronic check.

# %% [markdown]
# #**Q9.Please create an appropriate plot to check the count of payment methods and explain it.**

# %%
sns.countplot(x=data['Payment Method']) # using count plot to see the count of payment methods

# %% [markdown]
# **EXPLANATION**:
#
# 1.Electronic check are primary method was most used payment methods compare to all others.
#
# 2.Mailed check has mostly used after electronic check.
#
# 3.Rest of the payment methods are comes after mailed check.

# %% [markdown]
# #**Q10.Please create an appropriate plot to see the relationship between monthly charges and total charges.**

# %%
df = pd.get_dummies(data,drop_first=True) # using drop function 
data.head()  # head function shows first 5 rows of data set

# %% [markdown]
# **Using replace function to fill the empty values with nan and type as float64**

# %%
data['Total Charges'] = data['Total Charges'].replace(' ', np.nan) # Filling the blank values with the np.nan
data['Total Charges'] = data['Total Charges'].astype('float64') #Converting into float type

# %% [markdown]
# **filling missing values with medain in total charges**

# %%
data['Total Charges']=data['Total Charges'].fillna(data['Total Charges'].median()) #Replace the missing values with median of the feature

# %%
sns.scatterplot(x=data['Monthly Charges'], y=data['Total Charges']) #using scatter plot to get the relationship between monthly and total charges.

# %% [markdown]
# **EXPLANATION**:
#
# Here from the above graph it is clear that as the monthly charges are increasing we can experience the total charges also increase which shows the positive correlation too.
